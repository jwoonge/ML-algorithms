# %% [markdown]
# <a href="https://colab.research.google.com/github/jwoonge/ML-algorithms/blob/master/01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("this is for assginment01 of ML class")
print("20141261 송제웅")
# Out:
# this is for assginment01 of ML class
# 20141261 송제웅
